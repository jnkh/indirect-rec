# %%
# %pylab
N = 203
thetas = 2*pi*array(range(N))/N
thetass = 2*pi*(array(range(N))*3)/N

plot(cos(thetas))
plot(cos(thetass))
print sum(cos(thetas)*sin(thetas))
np.fft.fft(1 + cos(thetas))
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
# -3.64291929955e-15
# array([  2.03000000e+02 +0.00000000e+00j,
#          1.01500000e+02 -3.82442994e-15j,
#         -4.47966664e-14 +1.68355801e-15j,
#          1.68840130e-14 -2.10353919e-14j,
#         -7.34125703e-15 -6.61112230e-15j,
#          5.63117457e-17 -3.37016654e-16j,
#          4.52970994e-14 +6.43345405e-15j,
#         -1.22568622e-13 -1.38075600e-16j,
#         -5.79426585e-14 +2.47430340e-15j,
#          4.10023666e-16 -2.20229984e-15j,
#          5.82663664e-15 -6.02841123e-15j,
#         -1.76821007e-15 -6.97692413e-15j,
#          2.54760607e-16 +6.32202687e-16j,
#          6.39488462e-14 +1.11904659e-14j,
#          1.15463195e-13 +1.12498249e-15j,
#          5.65134327e-14 +1.20187183e-15j,
#          3.19586459e-15 -6.72782466e-16j,
#          8.18415163e-15 -3.32962167e-15j,
#          2.77496325e-15 -9.71233700e-16j,
#          2.58804279e-16 +3.68560460e-15j,
# ...
